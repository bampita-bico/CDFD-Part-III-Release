# %% [markdown]
# # CDFD Part III: Adaptive Flux Limitation Biology and Medicine
#
# ## Biological AFL Diagnostics
#
# This notebook is a lightweight viewer for release-local toy diagnostics generated by `AFL_Biological_Mujjabi_Tests.py`. The outputs illustrate parasitic-drain, boundary-covariance, autoimmune-boundary, and cycling-retention model behavior. They are not clinical validation, diagnostic devices, or treatment guidance.

# %%
import json
from pathlib import Path

root = Path('..').resolve()
for folder in ['paper_07', 'paper_08', 'paper_10', 'paper_17']:
    summary_path = root / 'outputs' / folder / 'summary.json'
    data = json.loads(summary_path.read_text())
    print(folder, '-', data.get('diagnostic'), '-', data.get('clinical_status'))
