# %% [markdown]
# # CDFD Part III: Adaptive Flux Limitation Biology and Medicine
#
# ## Adaptive Flux Limitation in Metabolic Disease Diagnostics
#
# This notebook is a lightweight viewer for release-local toy diagnostics generated by `AFL_Metabolism_Verification.py`. The outputs illustrate metabolic saturation and constraint-memory behavior in the public runtime. They are not clinical validation of insulin resistance, CKD, fibrosis, or any treatment strategy.

# %%
import json
from pathlib import Path

summary_path = Path('..').resolve() / 'outputs' / 'paper_05' / 'summary.json'
summary = json.loads(summary_path.read_text())
for name, payload in summary.items():
    final = payload['final_state']['psi_s']['mean']
    print(name, 'mean final Psi_s =', round(final, 4), '-', payload['clinical_status'])
